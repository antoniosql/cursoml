-- %% [markdown]
-- ![SolidQ](https://www.solidq.com/wp-content/uploads/2015/06/Logo-SolidQ-Web.gif)
--
-- ados

-- %% [markdown]
-- Tenemos una vista, llamada vTargetMail que tiene datos demográficos de los clientes, con el objetivo de intentar segmentarlos para diferentes comunicaciones comerciales. Son 18.484 filas, de las cuales, 9.132 son clientes que han comprado bicicletas.
--
-- De ellos, 4.481 están solteros, y 4.651 están casados
--
-- Los datos están bastante balanceados

-- %%
select max(orderdate)
from factInternetSales
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.361
-- <table><tr><th>(No column name)</th></tr><tr><td>2014-01-28 00:00:00.000</td></tr></table>

-- %% [markdown]
-- Consulta base para RFM

-- %%
select CustomerKey, max(OrderDate) as 'FechaUltimaVenta', DATEDIFF ( dy, max(OrderDate) , '12/31/2013') 'DiasUltimaVenta' , 
    Count(DISTINCT SalesOrderNumber) as 'NumeroVentas' , Sum(SalesAmount) ' TotalImporteVenta'
from FactInternetSales 
where orderdate < '01/01/2014'
group by CustomerKey
-- Out:
-- (17978 rows affected)
-- Displaying Top 5000 rows.
-- Total execution time: 00:00:06.234
-- ...
