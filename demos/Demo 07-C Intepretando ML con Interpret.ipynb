# %%
# !pip install -U interpret
# Out:
# Requirement already up-to-date: interpret in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (0.2.1)
# Requirement already satisfied, skipping upgrade: interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1 in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret) (0.2.1)
# Requirement already satisfied, skipping upgrade: dash-cytoscape>=0.1.1; extra == "dash" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (0.1.1)WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000242D98EFDC0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/interpret/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000242D9D03D00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/interpret/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000242D9DBC130>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/interpret/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000242D9D0DAF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/interpret/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000242D9D0DA00>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/interpret/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000242DA646820>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pillow/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000242DA6465B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pillow/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000242DA6322B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pillow/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000242DA632DF0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pillow/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.VerifiedHTTPSConnection object at 0x00000242DA64DB20>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/pillow/
# ERROR: Could not find a version that satisfies the requirement pillow==5.4.1 (from lime>=0.1.1.33; extra == "lime"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (from versions: none)
# ERROR: No matching distribution found for pillow==5.4.1 (from lime>=0.1.1.33; extra == "lime"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret)
# WARNING: You are using pip version 20.1.1; however, version 20.3.3 is available.
# You should consider upgrading via the 'c:\users\asoto\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
#
# Requirement already satisfied, skipping upgrade: requests>=2.19.0; extra == "dash" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (2.23.0)
# Requirement already satisfied, skipping upgrade: dash-table>=4.1.0; extra == "dash" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (4.7.0)
# Requirement already satisfied, skipping upgrade: dash>=1.0.0; extra == "dash" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.12.0)
# Requirement already satisfied, skipping upgrade: gevent>=1.3.6; extra == "dash" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (20.5.0)
# Requirement already satisfied, skipping upgrade: psutil>=5.6.2; extra == "debug" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (5.7.0)
# Requirement already satisfied, skipping upgrade: joblib>=0.11; extra == "decisiontree" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (0.14.1)
# Requirement already satisfied, skipping upgrade: lime>=0.1.1.33; extra == "lime" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages\lime-0.2.0.0-py3.8.egg (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (0.2.0.0)
# Requirement already satisfied, skipping upgrade: ipython>=7.4.0; extra == "notebook" in c:\users\asoto\appdata\roaming\python\python38\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (7.14.0)
# Requirement already satisfied, skipping upgrade: ipykernel>=5.1.0; extra == "notebook" in c:\users\asoto\appdata\roaming\python\python38\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (5.2.1)
# Requirement already satisfied, skipping upgrade: plotly>=3.8.1; extra == "plotly" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (4.7.1)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.18.1; extra == "required" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (0.23.2)
# Requirement already satisfied, skipping upgrade: pandas>=0.19.2; extra == "required" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.0.3)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1; extra == "required" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.4.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.1; extra == "required" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.18.4)
# Requirement already satisfied, skipping upgrade: SALib>=1.3.3; extra == "sensitivity" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.3.11)
# Requirement already satisfied, skipping upgrade: shap>=0.28.5; extra == "shap" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (0.36.0)
# Requirement already satisfied, skipping upgrade: dill>=0.2.5; extra == "shap" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (0.3.2)
# Requirement already satisfied, skipping upgrade: treeinterpreter>=0.2.2; extra == "treeinterpreter" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (0.2.2)
# Requirement already satisfied, skipping upgrade: dash-html-components in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from dash-cytoscape>=0.1.1; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.0.3)
# Requirement already satisfied, skipping upgrade: dash_renderer in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from dash-cytoscape>=0.1.1; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.4.1)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.0; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (2.9)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.0; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.0; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from requests>=2.19.0; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.25.9)
# Requirement already satisfied, skipping upgrade: Flask>=1.0.2 in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from dash>=1.0.0; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.1.2)
# Requirement already satisfied, skipping upgrade: flask-compress in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from dash>=1.0.0; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.5.0)
# Requirement already satisfied, skipping upgrade: dash-core-components==1.10.0 in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from dash>=1.0.0; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.10.0)
# Requirement already satisfied, skipping upgrade: future in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from dash>=1.0.0; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (0.18.2)
# Requirement already satisfied, skipping upgrade: cffi>=1.12.2; platform_python_implementation == "CPython" and sys_platform == "win32" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from gevent>=1.3.6; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (1.14.0)
# Requirement already satisfied, skipping upgrade: greenlet>=0.4.14; platform_python_implementation == "CPython" in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from gevent>=1.3.6; extra == "dash"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (0.4.15)
# Requirement already satisfied, skipping upgrade: matplotlib in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from lime>=0.1.1.33; extra == "lime"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (3.2.1)
# Requirement already satisfied, skipping upgrade: tqdm in c:\users\asoto\appdata\local\programs\python\python38\lib\site-packages (from lime>=0.1.1.33; extra == "lime"->interpret-core[dash,debug,decisiontree,ebm,lime,linear,notebook,plotly,required,sensitivity,shap,treeinterpreter]>=0.2.1->interpret) (4.46.0)

# %%
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

df = pd.read_csv(
    "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data",
    header=None)
df.columns = [
    "Age", "WorkClass", "fnlwgt", "Education", "EducationNum",
    "MaritalStatus", "Occupation", "Relationship", "Race", "Gender",
    "CapitalGain", "CapitalLoss", "HoursPerWeek", "NativeCountry", "Income"
]
train_cols = df.columns[0:-1]
label = df.columns[-1]
X = df[train_cols]
y = df[label].apply(lambda x: 0 if x == " <=50K" else 1) #Convertimos la etiqueta en 0 y 1

# Transformamos las variables categóricas para utilizar modelos de sklearn
X_enc = pd.get_dummies(X, prefix_sep='.')
feature_names = list(X_enc.columns)

seed = 1  
X_train, X_test, y_train, y_test = train_test_split(X_enc, y, test_size=0.20, random_state=seed)

# %%
#Entrenando el modelo

from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline

# Podemos incluir prepocesado, no solo el clasificador dentro de nuestro pipeline

pca = PCA()
rf = RandomForestClassifier(n_estimators=100, n_jobs=-1)

blackbox_model = Pipeline([('pca', pca), ('rf', rf)])
blackbox_model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('pca', PCA()), ('rf', RandomForestClassifier(n_jobs=-1))])

# %%
#Viendo el rendimiento

from interpret import show
from interpret.perf import ROC

blackbox_perf = ROC(blackbox_model.predict_proba).explain_perf(X_test, y_test, name='Blackbox')
show(blackbox_perf)
# Out:
# <!-- http://127.0.0.1:7001/2938007930288/ -->
# <iframe src="http://127.0.0.1:7001/2938007930288/" width=100% height=800 frameBorder="0"></iframe>

# %%
#Explicaciones locales

from interpret.blackbox import LimeTabular
from interpret import show

#Blackbox explainers need a predict function, and optionally a dataset
lime = LimeTabular(predict_fn=blackbox_model.predict_proba, data=X_train)

#Pick the instances to explain, optionally pass in labels if you have them
lime_local = lime.explain_local(X_test[:5], y_test[:5], name='LIME')

show(lime_local)
# Out:
# <!-- http://127.0.0.1:7001/2938048396160/ -->
# <iframe src="http://127.0.0.1:7001/2938048396160/" width=100% height=800 frameBorder="0"></iframe>

# %%
from interpret.blackbox import ShapKernel
import numpy as np

background_val = np.median(X_train, axis=0).reshape(1, -1)
shap = ShapKernel(predict_fn=blackbox_model.predict_proba, data=background_val, feature_names=feature_names)
shap_local = shap.explain_local(X_test[:5], y_test[:5], name='SHAP')
show(shap_local)
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 12.81it/s]
# <!-- http://127.0.0.1:7001/2938048926432/ -->
# <iframe src="http://127.0.0.1:7001/2938048926432/" width=100% height=800 frameBorder="0"></iframe>

# %%
#Explicaciones Globales
from interpret.blackbox import MorrisSensitivity

sensitivity = MorrisSensitivity(predict_fn=blackbox_model.predict_proba, data=X_train)
sensitivity_global = sensitivity.explain_global(name="Global Sensitivity")

show(sensitivity_global)

# %%
from interpret.blackbox import PartialDependence

pdp = PartialDependence(predict_fn=blackbox_model.predict_proba, data=X_train)
pdp_global = pdp.explain_global(name='Partial Dependence')

show(pdp_global)

# %%
show([blackbox_perf, lime_local, shap_local, sensitivity_global, pdp_global])
